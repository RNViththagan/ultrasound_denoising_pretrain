# %%
#%pip install git+https://github.com/Po-Hsun-Su/pytorch-ssim.git

# %%
# %run main.py --mode finetune --skip_pretrain --run_augmentation
# Out:
# 🕒 Run started at: 2025-05-01 20:36:28
# ✅ Using GPU: NVIDIA TITAN Xp
# 📸 Running augmentation with num_augmentations=5
# 🕒 Augmentation started at: 2025-05-01 20:36:28
# 📂 Input directory: ../Data_sets/BUSI/
# 📂 Output directory: ../Data_sets/BUSI_augmented/
# 📷 Processing 437 images in benign...
# Augmenting benign: 100%|██████████| 437/437 [03:05<00:00,  2.36it/s]
# 📷 Processing 228 images in malignant...
# Augmenting malignant: 100%|██████████| 228/228 [01:25<00:00,  2.67it/s]
# 📷 Processing 133 images in normal...
# Augmenting normal: 100%|██████████| 133/133 [01:05<00:00,  2.03it/s]
# ✅ Augmentation complete!
# Total Images Generated: 4788
# Class Counts: {'benign': 2622, 'malignant': 1368, 'normal': 798}
# 📊 Dataset Statistics:
# Total Images (Train): 3285
# Total Images (Val): 705
# Total Images (Test): 119
# Train Class Counts: {'benign': 2185, 'malignant': 1140, 'normal': 665}
# Test Class Counts: {'benign': 437, 'malignant': 228, 'normal': 133}
# ...

# %%
# %run test_finetune.py
# Out:
# 🕒 Run started at: 2025-05-02 06:16:43
# ✅ Using GPU: NVIDIA TITAN Xp
# 📊 Dataset Statistics:
# Total Images (Train): 3285
# Total Images (Val): 705
# Total Images (Test): 119
# Train Class Counts: {'benign': 2185, 'malignant': 1140, 'normal': 665}
# Test Class Counts: {'benign': 437, 'malignant': 228, 'normal': 133}
# Train/Val/Test Split: 3285/705/119 (70.0%/15.0%/15.0%)
# Sample Batch Shapes: Doubly-Noisy=torch.Size([8, 1, 256, 256]), Input=torch.Size([8, 1, 256, 256])
# ✅ Loaded weights from checkpoints/finetuned_resnet_noise0.1_final_2025-05-01_20-42-04.pth
# 🧪 Testing on 119 test images
# Testing Finetuned: 100%|██████████| 15/15 [00:02<00:00,  5.62it/s]
# 📊 Finetuned Test Results (Y_hat vs. Y, Noise Std=0.1):
# Average Test Loss: 0.0008
# Average Test PSNR: 30.86 dB
# Average Test SSIM: 0.9058
# 📸 Saved visualization to ./outs/2025-05-02_06-16-43/test_results_finetune_noise0.1.png
