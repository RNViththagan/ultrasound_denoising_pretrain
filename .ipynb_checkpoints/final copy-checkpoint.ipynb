# %% [markdown]
# # Ultrasound Denoising Experiments
#
# This notebook runs experiments with different noise standard deviations (0.1, 0.25, 0.5, 0.75) for ultrasound denoising using the UNet model. Each section contains experiments with different seeds for reproducibility.

# %% [markdown]
# ## Noise Standard Deviation 0.1
#
# Running experiments with noise_std=0.1 using different seeds.

# %%
# Default seed
# %run main.py --model unet --noise_std 0.1
# Out:
# 2025-11-11 18:29:49.185258: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 🕒 Run started at: 2025-11-11 18:29:51
# 🔥 Using GPU: NVIDIA TITAN Xp
# GPU Memory Allocated: 0.00 GB
# GPU Memory Cached: 0.00 GB
# 🌱 Using random seed: 97149
# 📊 Dataset Statistics (BUSI):
# Total Images (Train): 558
# Total Images (Test): 240
# Train Class Counts: {'benign': 303, 'malignant': 160, 'normal': 95}
# Test Class Counts: {'benign': 437, 'malignant': 228, 'normal': 133}
# Sample Image Path: ../Data_sets/BUSI/benign/benign (371).png
# Train/Test Split: 558/240 (70.0%/30.0%)
# Sample Batch Shapes: Masked=torch.Size([8, 1, 256, 256]), Original=torch.Size([8, 1, 256, 256]), Mask=torch.Size([8, 1, 256, 256])
# 📊 Dataset Statistics (BUSI):
# ...

# %%
# Seed 43
# %run main.py --model unet --noise_std 0.1 --seed 43
# Out:
# 🕒 Run started at: 2025-11-11 20:08:05
# 🔥 Using GPU: NVIDIA TITAN Xp
# GPU Memory Allocated: 0.00 GB
# GPU Memory Cached: 3.92 GB
# 🌱 Using random seed: 43
# 📊 Dataset Statistics (BUSI):
# Total Images (Train): 558
# Total Images (Test): 240
# Train Class Counts: {'benign': 301, 'malignant': 156, 'normal': 101}
# Test Class Counts: {'benign': 437, 'malignant': 228, 'normal': 133}
# Sample Image Path: ../Data_sets/BUSI/benign/benign (371).png
# Train/Test Split: 558/240 (70.0%/30.0%)
# Sample Batch Shapes: Masked=torch.Size([8, 1, 256, 256]), Original=torch.Size([8, 1, 256, 256]), Mask=torch.Size([8, 1, 256, 256])
# 📊 Dataset Statistics (BUSI):
# Total Images (Train): 558
# Total Images (Test): 240
# Train Class Counts: {'benign': 305, 'malignant': 161, 'normal': 92}
# Test Class Counts: {'benign': 437, 'malignant': 228, 'normal': 133}
# Sample Image Path: ../Data_sets/BUSI/benign/benign (371).png
# Train/Test Split: 558/240 (70.0%/30.0%)
# ...

# %%
# Seed 44
# %run main.py --model unet --noise_std 0.1 --seed 44
# Out:
# 🕒 Run started at: 2025-11-11 21:17:48
# 🔥 Using GPU: NVIDIA TITAN Xp
# GPU Memory Allocated: 0.05 GB
# GPU Memory Cached: 3.92 GB
# 🌱 Using random seed: 44
# 📊 Dataset Statistics (BUSI):
# Total Images (Train): 558
# Total Images (Test): 240
# Train Class Counts: {'benign': 301, 'malignant': 157, 'normal': 100}
# Test Class Counts: {'benign': 437, 'malignant': 228, 'normal': 133}
# Sample Image Path: ../Data_sets/BUSI/benign/benign (371).png
# Train/Test Split: 558/240 (70.0%/30.0%)
# Sample Batch Shapes: Masked=torch.Size([8, 1, 256, 256]), Original=torch.Size([8, 1, 256, 256]), Mask=torch.Size([8, 1, 256, 256])
# 📊 Dataset Statistics (BUSI):
# Total Images (Train): 558
# Total Images (Test): 240
# Train Class Counts: {'benign': 306, 'malignant': 159, 'normal': 93}
# Test Class Counts: {'benign': 437, 'malignant': 228, 'normal': 133}
# Sample Image Path: ../Data_sets/BUSI/benign/benign (371).png
# Train/Test Split: 558/240 (70.0%/30.0%)
# ...

# %%
import torch, gc

# Garbage collect & clear CUDA memory
gc.collect()
torch.cuda.empty_cache()
torch.cuda.ipc_collect()
torch.cuda.synchronize()

print("✅ GPU memory cleared.")
print(f"Allocated: {torch.cuda.memory_allocated()/1024**2:.2f} MB")
print(f"Reserved : {torch.cuda.memory_reserved()/1024**2:.2f} MB")

# %% [markdown]
# ## Noise Standard Deviation 0.25
#
# Running experiments with noise_std=0.25 using different seeds.

# %%
# Default seed
# %run main.py --model unet --noise_std 0.25

# %%
# Seed 44
# %run main.py --model unet --noise_std 0.25 --seed 44

# %%
# Seed 43
# %run main.py --model unet --noise_std 0.25 --seed 43

# %% [markdown]
# ## Noise Standard Deviation 0.5
#
# Running experiments with noise_std=0.5 using different seeds.

# %%
# Default seed
# %run main.py --model unet --noise_std 0.5

# %%
# Seed 43
# %run main.py --model unet --noise_std 0.5 --seed 43

# %%
# Seed 44
# %run main.py --model unet --noise_std 0.5 --seed 44

# %% [markdown]
# ## Noise Standard Deviation 0.75
#
# Running experiments with noise_std=0.75 using different seeds.

# %%
# Default seed
# %run main.py --model unet --noise_std 0.75

# %%
# Seed 43
# %run main.py --model unet --noise_std 0.75 --seed 43

# %%
# Seed 44
# %run main.py --model unet --noise_std 0.75 --seed 44

# %% [markdown]
# ## HC18 Dataset Experiments
#
# Running experiments with the HC18 dataset using different noise standard deviations (0.1, 0.25, 0.5, 0.75) and different seeds.
#
# ### HC18 - Noise Standard Deviation 0.1

# %%
# Default seed
# %run main.py --model unet --dataset hc18 --noise_std 0.1

# %%
# Seed 43
# %run main.py --model unet --dataset hc18 --noise_std 0.1 --seed 43

# %%
# Seed 44
# %run main.py --model unet --dataset hc18 --noise_std 0.1 --seed 44

# %% [markdown]
# ### HC18 - Noise Standard Deviation 0.25

# %%
# Default seed
# %run main.py --model unet --dataset hc18 --noise_std 0.25

# %%
# Seed 43
# %run main.py --model unet --dataset hc18 --noise_std 0.25 --seed 43

# %%
# Seed 44
# %run main.py --model unet --dataset hc18 --noise_std 0.25 --seed 44

# %% [markdown]
# ### HC18 - Noise Standard Deviation 0.5

# %%
# Default seed
# %run main.py --model unet --dataset hc18 --noise_std 0.5

# %%
# Seed 43
# %run main.py --model unet --dataset hc18 --noise_std 0.5 --seed 43

# %%
# Seed 44
# %run main.py --model unet --dataset hc18 --noise_std 0.5 --seed 44

# %% [markdown]
# ### HC18 - Noise Standard Deviation 0.75

# %%
# Default seed
# %run main.py --model unet --dataset hc18 --noise_std 0.75

# %%
# Seed 43
# %run main.py --model unet --dataset hc18 --noise_std 0.75 --seed 43

# %%
# Seed 44
# %run main.py --model unet --dataset hc18 --noise_std 0.75 --seed 44
