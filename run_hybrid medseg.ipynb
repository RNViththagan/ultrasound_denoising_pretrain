# %%
# %run main.py --model unet
# Out:
# 2025-08-20 14:00:39.938195: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 🕒 Run started at: 2025-08-20 14:00:42
# 🔥 Using GPU: NVIDIA TITAN Xp
# GPU Memory Allocated: 0.00 GB
# GPU Memory Cached: 0.00 GB
# 📊 Dataset Statistics (BUSI):
# Total Images (Train): 558
# Total Images (Test): 240
# Train Class Counts: {'benign': 318, 'malignant': 151, 'normal': 89}
# Test Class Counts: {'benign': 437, 'malignant': 228, 'normal': 133}
# Sample Image Path: ../Data_sets/BUSI/benign/benign (371).png
# Train/Test Split: 558/240 (70.0%/30.0%)
# Sample Batch Shapes: Masked=torch.Size([8, 1, 256, 256]), Original=torch.Size([8, 1, 256, 256]), Mask=torch.Size([8, 1, 256, 256])
# 📊 Dataset Statistics (BUSI):
# Total Images (Train): 558
# ...

# %%
# %run main.py --model resnet
# Out:
# 🕒 Run started at: 2025-08-20 15:14:01
# 🔥 Using GPU: NVIDIA TITAN Xp
# GPU Memory Allocated: 0.00 GB
# GPU Memory Cached: 3.92 GB
# 📊 Dataset Statistics (BUSI):
# Total Images (Train): 558
# Total Images (Test): 240
# Train Class Counts: {'benign': 318, 'malignant': 151, 'normal': 89}
# Test Class Counts: {'benign': 437, 'malignant': 228, 'normal': 133}
# Sample Image Path: ../Data_sets/BUSI/benign/benign (371).png
# Train/Test Split: 558/240 (70.0%/30.0%)
# Sample Batch Shapes: Masked=torch.Size([8, 1, 256, 256]), Original=torch.Size([8, 1, 256, 256]), Mask=torch.Size([8, 1, 256, 256])
# 📊 Dataset Statistics (BUSI):
# Total Images (Train): 558
# Total Images (Test): 240
# Train Class Counts: {'benign': 306, 'malignant': 158, 'normal': 94}
# Test Class Counts: {'benign': 437, 'malignant': 228, 'normal': 133}
# Sample Image Path: ../Data_sets/BUSI/benign/benign (371).png
# Train/Test Split: 558/240 (70.0%/30.0%)
# ...

# %%
#%run test_finetune.py --model unet --num_samples 4

# %%
# %run main.py --model both --noise_std 0.25
# Out:
# 🕒 Run started at: 2025-08-21 18:19:38
# 🔥 Using GPU: NVIDIA TITAN Xp
# GPU Memory Allocated: 0.11 GB
# GPU Memory Cached: 3.92 GB
# 📊 Dataset Statistics (BUSI):
# Total Images (Train): 558
# Total Images (Test): 240
# Train Class Counts: {'benign': 318, 'malignant': 151, 'normal': 89}
# Test Class Counts: {'benign': 437, 'malignant': 228, 'normal': 133}
# Sample Image Path: ../Data_sets/BUSI/benign/benign (371).png
# Train/Test Split: 558/240 (70.0%/30.0%)
# Sample Batch Shapes: Masked=torch.Size([8, 1, 256, 256]), Original=torch.Size([8, 1, 256, 256]), Mask=torch.Size([8, 1, 256, 256])
# 📊 Dataset Statistics (BUSI):
# Total Images (Train): 558
# Total Images (Test): 240
# Train Class Counts: {'benign': 306, 'malignant': 158, 'normal': 94}
# Test Class Counts: {'benign': 437, 'malignant': 228, 'normal': 133}
# Sample Image Path: ../Data_sets/BUSI/benign/benign (371).png
# Train/Test Split: 558/240 (70.0%/30.0%)
# ...

# %%
# %run main.py --model both --noise_std 0.5
# Out:
# 🕒 Run started at: 2025-08-21 21:55:12
# 🔥 Using GPU: NVIDIA TITAN Xp
# GPU Memory Allocated: 0.38 GB
# GPU Memory Cached: 4.01 GB
# 📊 Dataset Statistics (BUSI):
# Total Images (Train): 558
# Total Images (Test): 240
# Train Class Counts: {'benign': 318, 'malignant': 151, 'normal': 89}
# Test Class Counts: {'benign': 437, 'malignant': 228, 'normal': 133}
# Sample Image Path: ../Data_sets/BUSI/benign/benign (371).png
# Train/Test Split: 558/240 (70.0%/30.0%)
# Sample Batch Shapes: Masked=torch.Size([8, 1, 256, 256]), Original=torch.Size([8, 1, 256, 256]), Mask=torch.Size([8, 1, 256, 256])
# 📊 Dataset Statistics (BUSI):
# Total Images (Train): 558
# Total Images (Test): 240
# Train Class Counts: {'benign': 306, 'malignant': 158, 'normal': 94}
# Test Class Counts: {'benign': 437, 'malignant': 228, 'normal': 133}
# Sample Image Path: ../Data_sets/BUSI/benign/benign (371).png
# Train/Test Split: 558/240 (70.0%/30.0%)
# ...
