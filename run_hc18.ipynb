# %%
# %run main.py --model unet --dataset hc18
# Out:
# 2025-10-10 09:29:27.130113: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 🕒 Run started at: 2025-10-10 09:29:29
# 🔥 Using GPU: NVIDIA TITAN Xp
# GPU Memory Allocated: 0.00 GB
# GPU Memory Cached: 0.00 GB
# 📊 Dataset Statistics (HC18):
# Total Images (Train): 933
# Total Images (Test): 401
# Train Class Counts: {'hc18': 933}
# Test Class Counts: {'hc18': 1334}
# Sample Image Path: ../Data_sets/HC18/test_set/029_HC.png
# Train/Test Split: 933/401 (70.0%/30.0%)
# Sample Batch Shapes: Masked=torch.Size([8, 1, 256, 256]), Original=torch.Size([8, 1, 256, 256]), Mask=torch.Size([8, 1, 256, 256])
# 📊 Dataset Statistics (HC18):
# Total Images (Train): 933
# Total Images (Test): 401
# Train Class Counts: {'hc18': 933}
# ...

# %%
# %run main.py --model unet --dataset hc18
# Out:
# 🕒 Run started at: 2025-10-10 14:52:08
# 🔥 Using GPU: NVIDIA TITAN Xp
# GPU Memory Allocated: 0.02 GB
# GPU Memory Cached: 3.92 GB
# 📊 Dataset Statistics (HC18):
# Total Images (Train): 933
# Total Images (Test): 401
# Train Class Counts: {'hc18': 933}
# Test Class Counts: {'hc18': 1334}
# Sample Image Path: ../Data_sets/HC18/test_set/029_HC.png
# Train/Test Split: 933/401 (70.0%/30.0%)
# Sample Batch Shapes: Masked=torch.Size([8, 1, 256, 256]), Original=torch.Size([8, 1, 256, 256]), Mask=torch.Size([8, 1, 256, 256])
# 📊 Dataset Statistics (HC18):
# Total Images (Train): 933
# Total Images (Test): 401
# Train Class Counts: {'hc18': 933}
# Test Class Counts: {'hc18': 1334}
# Sample Image Path: ../Data_sets/HC18/test_set/029_HC.png
# Train/Test Split: 933/401 (70.0%/30.0%)
# Sample Batch Shapes: Doubly-Noisy=torch.Size([8, 1, 256, 256]), Input=torch.Size([8, 1, 256, 256])
#
# 🚀 Processing model: UNET
# ⚠️ No pretrained weights provided. Initializing MedSegUNet from scratch.
#
# ...

# %%
# %run main.py --model unet --dataset hc18
# Out:
# 🕒 Run started at: 2025-10-10 12:40:03
# 🔥 Using GPU: NVIDIA TITAN Xp
# GPU Memory Allocated: 0.02 GB
# GPU Memory Cached: 3.92 GB
# 📊 Dataset Statistics (HC18):
# Total Images (Train): 933
# Total Images (Test): 401
# Train Class Counts: {'hc18': 933}
# Test Class Counts: {'hc18': 1334}
# Sample Image Path: ../Data_sets/HC18/test_set/029_HC.png
# Train/Test Split: 933/401 (70.0%/30.0%)
# Sample Batch Shapes: Masked=torch.Size([8, 1, 256, 256]), Original=torch.Size([8, 1, 256, 256]), Mask=torch.Size([8, 1, 256, 256])
# 📊 Dataset Statistics (HC18):
# Total Images (Train): 933
# Total Images (Test): 401
# Train Class Counts: {'hc18': 933}
# Test Class Counts: {'hc18': 1334}
# Sample Image Path: ../Data_sets/HC18/test_set/029_HC.png
# Train/Test Split: 933/401 (70.0%/30.0%)
# Sample Batch Shapes: Doubly-Noisy=torch.Size([8, 1, 256, 256]), Input=torch.Size([8, 1, 256, 256])
#
# 🚀 Processing model: UNET
# ⚠️ No pretrained weights provided. Initializing MedSegUNet from scratch.
#
# ...

# %%
# %run main.py --model unet --dataset hc18 --seed 42
# Out:
# 2025-10-24 23:22:41.735458: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 🕒 Run started at: 2025-10-24 23:22:45
# 🔥 Using GPU: NVIDIA TITAN Xp
# GPU Memory Allocated: 0.00 GB
# GPU Memory Cached: 0.00 GB
# 🌱 Using random seed: 42
# 📊 Dataset Statistics (HC18):
# Total Images (Train): 933
# Total Images (Test): 401
# Train Class Counts: {'hc18': 933}
# Test Class Counts: {'hc18': 1334}
# Sample Image Path: ../Data_sets/HC18/test_set/029_HC.png
# Train/Test Split: 933/401 (70.0%/30.0%)
# Sample Batch Shapes: Masked=torch.Size([8, 1, 256, 256]), Original=torch.Size([8, 1, 256, 256]), Mask=torch.Size([8, 1, 256, 256])
# 📊 Dataset Statistics (HC18):
# Total Images (Train): 933
# Total Images (Test): 401
# ...

# %%
# %run main.py --model unet --dataset hc18 --seed 43
# Out:
# 🕒 Run started at: 2025-10-25 01:25:53
# 🔥 Using GPU: NVIDIA TITAN Xp
# GPU Memory Allocated: 0.00 GB
# GPU Memory Cached: 3.92 GB
# 🌱 Using random seed: 43
# 📊 Dataset Statistics (HC18):
# Total Images (Train): 933
# Total Images (Test): 401
# Train Class Counts: {'hc18': 933}
# Test Class Counts: {'hc18': 1334}
# Sample Image Path: ../Data_sets/HC18/test_set/029_HC.png
# Train/Test Split: 933/401 (70.0%/30.0%)
# Sample Batch Shapes: Masked=torch.Size([8, 1, 256, 256]), Original=torch.Size([8, 1, 256, 256]), Mask=torch.Size([8, 1, 256, 256])
# 📊 Dataset Statistics (HC18):
# Total Images (Train): 933
# Total Images (Test): 401
# Train Class Counts: {'hc18': 933}
# Test Class Counts: {'hc18': 1334}
# Sample Image Path: ../Data_sets/HC18/test_set/029_HC.png
# Train/Test Split: 933/401 (70.0%/30.0%)
# Sample Batch Shapes: Doubly-Noisy=torch.Size([8, 1, 256, 256]), Input=torch.Size([8, 1, 256, 256])
#
# 🚀 Processing model: UNET
# ...

# %%
# %run main.py --model unet --dataset hc18 --seed 44
# Out:
# 🕒 Run started at: 2025-10-25 03:28:53
# 🔥 Using GPU: NVIDIA TITAN Xp
# GPU Memory Allocated: 0.00 GB
# GPU Memory Cached: 3.92 GB
# 🌱 Using random seed: 44
# 📊 Dataset Statistics (HC18):
# Total Images (Train): 933
# Total Images (Test): 401
# Train Class Counts: {'hc18': 933}
# Test Class Counts: {'hc18': 1334}
# Sample Image Path: ../Data_sets/HC18/test_set/029_HC.png
# Train/Test Split: 933/401 (70.0%/30.0%)
# Sample Batch Shapes: Masked=torch.Size([8, 1, 256, 256]), Original=torch.Size([8, 1, 256, 256]), Mask=torch.Size([8, 1, 256, 256])
# 📊 Dataset Statistics (HC18):
# Total Images (Train): 933
# Total Images (Test): 401
# Train Class Counts: {'hc18': 933}
# Test Class Counts: {'hc18': 1334}
# Sample Image Path: ../Data_sets/HC18/test_set/029_HC.png
# Train/Test Split: 933/401 (70.0%/30.0%)
# Sample Batch Shapes: Doubly-Noisy=torch.Size([8, 1, 256, 256]), Input=torch.Size([8, 1, 256, 256])
#
# 🚀 Processing model: UNET
# ...
