# %%
# %run main.py --model unet --noise_std 0.5
# Out:
# 2025-11-11 17:28:41.556786: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 🕒 Run started at: 2025-11-11 17:28:43
# 🔥 Using GPU: NVIDIA TITAN Xp
# GPU Memory Allocated: 0.00 GB
# GPU Memory Cached: 0.00 GB
# 🌱 Using random seed: 40094
# 📊 Dataset Statistics (BUSI):
# Total Images (Train): 558
# Total Images (Test): 240
# Train Class Counts: {'benign': 314, 'malignant': 159, 'normal': 85}
# Test Class Counts: {'benign': 437, 'malignant': 228, 'normal': 133}
# Sample Image Path: ../Data_sets/BUSI/benign/benign (371).png
# Train/Test Split: 558/240 (70.0%/30.0%)
# Sample Batch Shapes: Masked=torch.Size([8, 1, 256, 256]), Original=torch.Size([8, 1, 256, 256]), Mask=torch.Size([8, 1, 256, 256])
# 📊 Dataset Statistics (BUSI):
# Total Images (Train): 558
# Total Images (Test): 240
# Train Class Counts: {'benign': 306, 'malignant': 164, 'normal': 88}
# Test Class Counts: {'benign': 437, 'malignant': 228, 'normal': 133}
# Sample Image Path: ../Data_sets/BUSI/benign/benign (371).png
# Train/Test Split: 558/240 (70.0%/30.0%)
# Rayleigh noise generated
# Rayleigh noise generated
# Rayleigh noise generated
# Rayleigh noise generated
# Rayleigh noise generated
# Rayleigh noise generated
# Rayleigh noise generated
# Rayleigh noise generated
# Sample Batch Shapes: Doubly-Noisy=torch.Size([8, 1, 256, 256]), Input=torch.Size([8, 1, 256, 256])
#
# 🚀 Processing model: UNET
# ⚠️ No pretrained weights provided. Initializing MedSegUNet from scratch.
#
# 🚀 Starting Pretraining (Noise2Void) for UNET...
# [Pretrain Epoch 1/150]:  69%|██████▊   | 48/70 [00:11<00:05,  4.08it/s, loss=0.762, psnr=1.18, ssim=0.0393]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /media/siyam/Research/Viththagan/ultrasound_denoising_pretrain/main.py:132
#     129 parser.add_argument('--use_checkpoint', action='store_true', default=False,
#     130                     help="Use existing pretrained checkpoint if available")
#     131 args = parser.parse_args()
# --> 132 main(args)
#
# File /media/siyam/Research/Viththagan/ultrasound_denoising_pretrain/main.py:99, in main(args)
#      97 if not args.skip_pretrain:
#      98     print(f"\n🚀 Starting Pretraining (Noise2Void) for {model_name.upper()}...")
# ---> 99     pretrain(model, train_loader_pretrain, None, config)
#     100     test_pretrain(model, test_loader_pretrain, config)
#     102 # Finetune (Noisier2Noise)
#
# File /media/siyam/Research/Viththagan/ultrasound_denoising_pretrain/train.py:41, in pretrain(model, train_loader, val_loader, config)
#      38 running_ssim = 0
#      40 loop = tqdm(train_loader, desc=f"[Pretrain Epoch {epoch+1}/{config.pretrain_epochs}]")
# ---> 41 for masked_image, original_image, mask, img_path in loop:
#      42     masked_image = masked_image.to(config.device)
#      43     original_image = original_image.to(config.device)
#
# File ~/anaconda3/envs/dl/lib/python3.12/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File ~/anaconda3/envs/dl/lib/python3.12/site-packages/torch/utils/data/dataloader.py:708, in _BaseDataLoaderIter.__next__(self)
#     705 if self._sampler_iter is None:
#     706     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     707     self._reset()  # type: ignore[call-arg]
# --> 708 data = self._next_data()
#     709 self._num_yielded += 1
#     710 if (
#     711     self._dataset_kind == _DatasetKind.Iterable
#     712     and self._IterableDataset_len_called is not None
#     713     and self._num_yielded > self._IterableDataset_len_called
#     714 ):
#
# File ~/anaconda3/envs/dl/lib/python3.12/site-packages/torch/utils/data/dataloader.py:764, in _SingleProcessDataLoaderIter._next_data(self)
#     762 def _next_data(self):
#     763     index = self._next_index()  # may raise StopIteration
# --> 764     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     765     if self._pin_memory:
#     766         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/anaconda3/envs/dl/lib/python3.12/site-packages/torch/utils/data/_utils/fetch.py:50, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      48 if self.auto_collation:
#      49     if hasattr(self.dataset, "__getitems__") and self.dataset.__getitems__:
# ---> 50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
#      52         data = [self.dataset[idx] for idx in possibly_batched_index]
#
# File ~/anaconda3/envs/dl/lib/python3.12/site-packages/torch/utils/data/dataset.py:420, in Subset.__getitems__(self, indices)
#     418     return self.dataset.__getitems__([self.indices[idx] for idx in indices])  # type: ignore[attr-defined]
#     419 else:
# --> 420     return [self.dataset[self.indices[idx]] for idx in indices]
#
# File /media/siyam/Research/Viththagan/ultrasound_denoising_pretrain/dataset.py:88, in UltrasoundDataset.__getitem__(self, idx)
#      86 img_path = self.image_paths[idx]
#      87 try:
# ---> 88     image = Image.open(img_path).convert('L')
#      89 except Exception as e:
#      90     print(f"Error loading image {img_path}: {e}")
#
# File ~/anaconda3/envs/dl/lib/python3.12/site-packages/PIL/Image.py:984, in Image.convert(self, mode, matrix, dither, palette, colors)
#     981 if mode in ("BGR;15", "BGR;16", "BGR;24"):
#     982     deprecate(mode, 12)
# --> 984 self.load()
#     986 has_transparency = "transparency" in self.info
#     987 if not mode and self.mode == "P":
#     988     # determine default mode
#
# File ~/anaconda3/envs/dl/lib/python3.12/site-packages/PIL/ImageFile.py:300, in ImageFile.load(self)
#     297         raise OSError(msg)
#     299 b = b + s
# --> 300 n, err_code = decoder.decode(b)
#     301 if n < 0:
#     302     break
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# %run main.py --model unet --noise_std 0.5 --seed 43

# %%
# %run main.py --model unet --noise_std 0.5 --seed 44

# %%
# %run main.py --model unet --dataset hc18 --noise_std 0.5

# %%
# %run main.py --model unet --dataset hc18 --noise_std 0.5 --seed 43

# %%
# %run main.py --model unet --dataset hc18 --noise_std 0.5 --seed 44
